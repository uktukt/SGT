# %% [markdown]
# # Day 15
# ## Dovilė
# ![Not my picture](https://st2.depositphotos.com/1001911/7684/v/600/depositphotos_76840867-stock-illustration-pointing-at-himself-emoticon.jpg)

# %%
print("Hello Notebooks!")
# Out:
# Hello Notebooks!

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Homework (day14) doesn't work properly, but **check this out:**

# %%
x = np.linspace(-10, 10, 21)
y = x**3 + 5

# %%
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)
